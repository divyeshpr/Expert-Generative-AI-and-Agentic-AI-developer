# %% [markdown]
#  # Dictionary

# %%
mydict = dict()
mydict
# Out:
# {}

# %%
mydict = {1:'one',2:'Two',3:'Three'}
mydict
# Out:
# {1: 'one', 2: 'Two', 3: 'Three'}

# %%
del mydict
mydict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 del mydict
# ----> 2 mydict
#
# NameError: name 'mydict' is not defined

# %%
mydict = dict({1: 'one', 2: 'Two', 3: 'Three'})
mydict
# Out:
# {1: 'one', 2: 'Two', 3: 'Three'}

# %%
mydict1 = {"A":'one','B':'Two','C':'Three'}
mydict1
# Out:
# {'A': 'one', 'B': 'Two', 'C': 'Three'}

# %%
mydict1.keys()
# Out:
# dict_keys(['A', 'B', 'C'])

# %%
mydict1.values()
# Out:
# dict_values(['one', 'Two', 'Three'])

# %%
type(mydict1)
# Out:
# dict

# %%
print(type(mydict1))
# Out:
# <class 'dict'>

# %%
mydict1.items()
# Out:
# dict_items([('A', 'one'), ('B', 'Two'), ('C', 'Three')])

# %%
mydict2 = {1:'one','two':2,3:[1,2,3,4],'four':['A','B','C'],5:{1,2,3,4,5,6}}
mydict2
# Out:
# {1: 'one',
#  'two': 2,
#  3: [1, 2, 3, 4],
#  'four': ['A', 'B', 'C'],
#  5: {1, 2, 3, 4, 5, 6}}

# %%
mydict2[6]='six'
mydict2
# Out:
# {1: 'one',
#  'two': 2,
#  3: [1, 2, 3, 4],
#  'four': ['A', 'B', 'C'],
#  5: {1, 2, 3, 4, 5, 6},
#  6: 'six'}

# %%
mydict3 = {'a','b','c','d'}
mydict3
# Out:
# {'a', 'b', 'c', 'd'}

# %%
type(mydict3)
# Out:
# set

# %%
mydict3
# Out:
# {'a', 'b', 'c', 'd'}

# %%
mydict4 = dict.fromkeys(mydict3)
mydict4
# Out:
# {'c': None, 'b': None, 'd': None, 'a': None}

# %%
value = 'Divyesh'
mydict4=dict.fromkeys(mydict3,value)
mydict4
# Out:
# {'c': 'Divyesh', 'b': 'Divyesh', 'd': 'Divyesh', 'a': 'Divyesh'}

# %%
keys={1,2,3,4,5,6,7,8,9}
value = ['A','B','C']
mydict5 = dict.fromkeys(keys,value)
mydict5
# Out:
# {1: ['A', 'B', 'C'],
#  2: ['A', 'B', 'C'],
#  3: ['A', 'B', 'C'],
#  4: ['A', 'B', 'C'],
#  5: ['A', 'B', 'C'],
#  6: ['A', 'B', 'C'],
#  7: ['A', 'B', 'C'],
#  8: ['A', 'B', 'C'],
#  9: ['A', 'B', 'C']}

# %%
value.append('d')
mydict5
# Out:
# {1: ['A', 'B', 'C', 'd'],
#  2: ['A', 'B', 'C', 'd'],
#  3: ['A', 'B', 'C', 'd'],
#  4: ['A', 'B', 'C', 'd'],
#  5: ['A', 'B', 'C', 'd'],
#  6: ['A', 'B', 'C', 'd'],
#  7: ['A', 'B', 'C', 'd'],
#  8: ['A', 'B', 'C', 'd'],
#  9: ['A', 'B', 'C', 'd']}

# %%
value2 =value.copy()
mydict5 =dict.fromkeys(keys,value2)
mydict5
# Out:
# {1: ['A', 'B', 'C', 'd'],
#  2: ['A', 'B', 'C', 'd'],
#  3: ['A', 'B', 'C', 'd'],
#  4: ['A', 'B', 'C', 'd'],
#  5: ['A', 'B', 'C', 'd'],
#  6: ['A', 'B', 'C', 'd'],
#  7: ['A', 'B', 'C', 'd'],
#  8: ['A', 'B', 'C', 'd'],
#  9: ['A', 'B', 'C', 'd']}

# %%
mydict5 =dict.fromkeys(keys,value)
mydict5
# Out:
# {1: ['A', 'B', 'C', 'd'],
#  2: ['A', 'B', 'C', 'd'],
#  3: ['A', 'B', 'C', 'd'],
#  4: ['A', 'B', 'C', 'd'],
#  5: ['A', 'B', 'C', 'd'],
#  6: ['A', 'B', 'C', 'd'],
#  7: ['A', 'B', 'C', 'd'],
#  8: ['A', 'B', 'C', 'd'],
#  9: ['A', 'B', 'C', 'd']}

# %%
value.clear()

# %%
mydict5
# Out:
# {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7: [], 8: [], 9: []}

# %%
mydict5 =dict.fromkeys(keys,value2)
mydict5
# Out:
# {1: ['A', 'B', 'C', 'd'],
#  2: ['A', 'B', 'C', 'd'],
#  3: ['A', 'B', 'C', 'd'],
#  4: ['A', 'B', 'C', 'd'],
#  5: ['A', 'B', 'C', 'd'],
#  6: ['A', 'B', 'C', 'd'],
#  7: ['A', 'B', 'C', 'd'],
#  8: ['A', 'B', 'C', 'd'],
#  9: ['A', 'B', 'C', 'd']}

# %%
value2 =value.copy()

# %%
value2.count('A')
# Out:
# 0

# %%
mydict5
# Out:
# {1: ['A', 'B', 'C', 'd'],
#  2: ['A', 'B', 'C', 'd'],
#  3: ['A', 'B', 'C', 'd'],
#  4: ['A', 'B', 'C', 'd'],
#  5: ['A', 'B', 'C', 'd'],
#  6: ['A', 'B', 'C', 'd'],
#  7: ['A', 'B', 'C', 'd'],
#  8: ['A', 'B', 'C', 'd'],
#  9: ['A', 'B', 'C', 'd']}

# %%
mydict5[1]
# Out:
# ['A', 'B', 'C', 'd']

# %%
mydict2
# Out:
# {1: 'one',
#  'two': 2,
#  3: [1, 2, 3, 4],
#  'four': ['A', 'B', 'C'],
#  5: {1, 2, 3, 4, 5, 6},
#  6: 'six'}

# %%
mydict2['four']
# Out:
# ['A', 'B', 'C']

# %%
mydict2[6]
# Out:
# 'six'

# %%
mydict7 = {'Name':'Divyesh','Surname':'Prajapati'}
mydict7
# Out:
# {'Name': 'Divyesh', 'Surname': 'Prajapati'}

# %%
mydict7['DOB']='30/03/1987'
mydict7
# Out:
# {'Name': 'Divyesh', 'Surname': 'Prajapati', 'DOB': '30/03/1987'}

# %%
d = {'DOB':1987}
mydict7.update(d)

# %%
mydict7
# Out:
# {'Name': 'Divyesh', 'Surname': 'Prajapati', 'DOB': 1987}

# %%
mydict7['JOB']='IT'
mydict7
# Out:
# {'Name': 'Divyesh', 'Surname': 'Prajapati', 'DOB': 1987, 'JOB': 'IT'}

# %%
mydict7.pop('JOB')
mydict7
# Out:
# {'Name': 'Divyesh', 'Surname': 'Prajapati', 'DOB': 1987}

# %%
mydict7.popitem()
mydict7
# Out:
# {'Name': 'Divyesh', 'Surname': 'Prajapati'}

# %%
my_dict= {'Name': 'Divyesh', 'Surname': 'Prajapati', 'DOB': '30/03/1987'}
my_dict
# Out:
# {'Name': 'Divyesh', 'Surname': 'Prajapati', 'DOB': '30/03/1987'}

# %%
my_dict1 = my_dict

# %%
my_dict1
# Out:
# {'Name': 'Divyesh', 'Surname': 'Prajapati', 'DOB': '30/03/1987'}

# %%
id(my_dict1),id(my_dict)
# Out:
# (2331418430400, 2331418430400)

# %%
my_dict2 = my_dict.copy()
id(my_dict2)
# Out:
# 2331417478336

# %%
id(my_dict1),id(my_dict)
# Out:
# (2331418430400, 2331418430400)

# %%
my_dict['Address']='HMT'
my_dict
# Out:
# {'Name': 'Divyesh',
#  'Surname': 'Prajapati',
#  'DOB': '30/03/1987',
#  'Address': 'HMT'}

# %%
my_dict1
# Out:
# {'Name': 'Divyesh',
#  'Surname': 'Prajapati',
#  'DOB': '30/03/1987',
#  'Address': 'HMT'}

# %%
id(my_dict1),id(my_dict)
# Out:
# (2331418430400, 2331418430400)

# %%
for i in my_dict:
    print(i)
# Out:
# Name
# Surname
# DOB
# Address

# %%
for i in enumerate(my_dict):
    print(i)
# Out:
# (0, 'Name')
# (1, 'Surname')
# (2, 'DOB')
# (3, 'Address')

# %%
my_dict
# Out:
# {'Name': 'Divyesh',
#  'Surname': 'Prajapati',
#  'DOB': '30/03/1987',
#  'Address': 'HMT'}

# %%
'Divyesh' in my_dict
# Out:
# False

# %%
'Address' in my_dict
# Out:
# True

# %%
all(my_dict)
# Out:
# True

# %%
my_dict['Address'] = 'Nadiad'
my_dict
# Out:
# {'Name': 'Divyesh',
#  'Surname': 'Prajapati',
#  'DOB': '30/03/1987',
#  'Address': 'Nadiad'}

# %%
my_dict['Address'] = 0
my_dict
# Out:
# {'Name': 'Divyesh', 'Surname': 'Prajapati', 'DOB': '30/03/1987', 'Address': 0}

# %%
all(my_dict)
# Out:
# True

# %%
my_dict['Address'] = False
my_dict
# Out:
# {'Name': 'Divyesh',
#  'Surname': 'Prajapati',
#  'DOB': '30/03/1987',
#  'Address': False}

# %%
all(my_dict)
# Out:
# True

# %%
value = 0
my_dict={value}
my_dict
# Out:
# {0}

# %%
my_dict
# Out:
# {0}

# %%
all(my_dict)
# Out:
# False

# %%
my_dict= {'Name': 'Divyesh',
 'Surname': 'Prajapati',
 'DOB': '30/03/1987',
 'Address': False}

# %%
my_dict
# Out:
# {'Name': 'Divyesh',
#  'Surname': 'Prajapati',
#  'DOB': '30/03/1987',
#  'Address': False}

# %%
my_dict= {'Name': 0,
 'Surname': 0,
 'DOB': 0,
 'Address': 0}
my_dict
# Out:
# {'Name': 0, 'Surname': 0, 'DOB': 0, 'Address': 0}

# %%
all(my_dict)
# Out:
# True

# %%
my_dict= {'Name': 0}
my_dict
# Out:
# {'Name': 0}

# %%
all(my_dict)
# Out:
# True

# %%
my_dict= {0}
my_dict
# Out:
# {0}

# %%
all(my_dict)
# Out:
# False
