# %% [markdown]
# # Operators

# %%
a = 5
b = 2

# %%
a
# Out:
# 5

# %%
b
# Out:
# 2

# %%
a>b
# Out:
# True

# %%
sum = a+b
sum
# Out:
# 7

# %%
sum = a-b
sum
# Out:
# 3

# %%
mul = a*b
mul
# Out:
# 10

# %%
div=a/b
div
# Out:
# 2.5

# %%
div = a//b
div
# Out:
# 2

# %% [markdown]
# - Comparision Operator

# %%
equal = a==b
print("Is equal:", equal)
# Out:
# Is equal: False

# %%
a==b
# Out:
# False

# %%
a=b

# %%
equal = a==b
print("Is equal:", equal)
# Out:
# Is equal: True

# %%
a =5 
b =6

# %%
g = a>b
print(f"{a} Is greater than {b} :", g)
# Out:
# 5 Is greater than 6 : False

# %%
g=b>a
print(f"{b} Is greater than {a} :", g)
# Out:
# 6 Is greater than 5 : True

# %% [markdown]
# - Unary Operators

# %%
number = 10 
result = -number
print("Unary minus Operaton:",result)
# Out:
# Unary minus Operaton: -10

# %%
number = 10 
result = +number
print("Unary plus Operaton:",result)
# Out:
# Unary plus Operaton: 10

# %%
n = 10 
m=11
result = m>n
print("Logical Not Operator:",not result)
# Out:
# Logical Not Operator: False

# %%
a = 5 
b = 3 
addition_result = a + b 
print("Binary Addition Operator:", addition_result)
# Out:
# Binary Addition Operator: 8

# %%
bitwise_and_result = a & b 
print("Bitwise AND Operator:", bitwise_and_result)
# Out:
# Bitwise AND Operator: 1

# %%
result = 5 + 3 * 2 / 2 - (4 % 3) ** 2
print("Result:", result)
# Out:
# Result: 7.0

# %% [markdown]
# - Relational Operator

# %%
a =5
b = 6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a*b
# Out:
# 30

# %%
a ==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
b>=a
# Out:
# True

# %%
b<=a
# Out:
# False

# %% [markdown]
# - Logical Operator

# %% [markdown]
# # AND OR and NOT are the logical operator

# %%
a = 5
b = 6

# %%
a<8 and b<8
# Out:
# True

# %%
a<8 or b<8
# Out:
# True

# %%
a>8 and b<8
# Out:
# False

# %%
a<8 or b>8
# Out:
# True

# %%
a<8 & b<8
# Out:
# False

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
x = False

# %%
not x
# Out:
# True

# %%
a = 5
b = 6

# %%
a or  b
# Out:
# 5

# %%
a = 5 
b = 3

# %%
bitwise_and_result = a & b 
print("Bitwise AND Operator:", bitwise_and_result)
# Out:
# Bitwise AND Operator: 1

# %%
bitwise_and_result
# Out:
# 1

# %%
not bitwise_and_result
# Out:
# False

# %% [markdown]
# - Numbers

# %%
a =25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
int(0b11011)
# Out:
# 27

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
int(0b11111)
# Out:
# 31

# %%
0x9
# Out:
# 9

# %%
0x8
# Out:
# 8

# %%
0xd
# Out:
# 13

# %%
0xf
# Out:
# 15

# %% [markdown]
# # Bitwise Operator

# %%
bin(12)
# Out:
# '0b1100'

# %%
print(bin(12))
# Out:
# 0b1100

# %%
~12
# Out:
# -13

# %%
print(bin(13))
# Out:
# 0b1101

# %%
~13
# Out:
# -14

# %%
~-12
# Out:
# 11

# %%
~-13
# Out:
# 12

# %%
a
# Out:
# 25

# %%
a =5
b =6

# %%
a & b
# Out:
# 4

# %%
a | b
# Out:
# 7

# %%
a ^ b
# Out:
# 3

# %%
35^40
# Out:
# 11

# %% [markdown]
# - left shift <<   --> we gain the bit
# - right shift >> --> we loose the bit

# %%
12 <<2
# Out:
# 48

# %%
12 <<3
# Out:
# 96

# %%
12 >>2
# Out:
# 3

# %% [markdown]
# - Swap the variable

# %%
a , b = 5 ,6

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
a = a + b
a
# Out:
# 11

# %%
b = a-b
b
# Out:
# 5

# %%
a = a-b
a
# Out:
# 6

# %%
a , b = 5 ,6

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
a , b = b,a

# %%
a
# Out:
# 6

# %%
b
# Out:
# 5

# %%
a , b = 5 ,6

# %%
a = a ^ b
a
# Out:
# 3

# %%
b = a ^ b
b
# Out:
# 5

# %%
a = a ^ b
a
# Out:
# 6
