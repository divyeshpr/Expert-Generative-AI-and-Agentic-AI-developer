# %% [markdown]
# Python Type Casting

# %%
int(100.2)
# Out:
# 100

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# 1) While we do type casting other datatype to int--> complex and string with text are not possible
# 2) while we do type casting, only 1 argument can be passed

# %%
Type casting for Float from other

# %%
float(25)
# Out:
# 25.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('8')
# Out:
# 8.0

# %% [markdown]
# 1) While we do type casting other datatype to float--> complex and string with text are not possible
# 2) while we do type casting, only 1 argument can be passed

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex(10.5,33.33)
# Out:
# (10.5+33.33j)

# %%
complex(False,True)
# Out:
# 1j

# %%
complex(True,True)
# Out:
# (1+1j)

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex('10','15')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 complex('10','15')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex('10',15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 complex('10',15)
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10,'15')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 complex(10,'15')
#
# TypeError: complex() second arg can't be a string

# %%
complex('15')
# Out:
# (15+0j)

# %% [markdown]
# 1) While we do type casting other datatype to complex--> string with text are not possible
# 2) while we do type casting, max 2 argument can be passed
# 3) while type casting to complex-- if there are two arguments and one of them is string then it is not possible

# %%
complex (int('10'),int('20'))
# Out:
# (10+20j)

# %%
str(2)
# Out:
# '2'

# %%
str(2.3)
# Out:
# '2.3'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %% [markdown]
# --we can type case to other without any issye

# %%
bool(10)
# Out:
# True

# %%
bool(100000000)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool( )
# Out:
# False

# %%
bool(1+10j)
# Out:
# True

# %%
bool('Divyesh')
# Out:
# True

# %% [markdown]
# we can do type cast to bool from other without any issue. any non-zero number will consider as 1 (True)

# %%
print(10)
print(10,20)
print('Python')
print(10,20,'Python')
# Out:
# 10
# 10 20
# Python
# 10 20 Python

# %%
#Print can take multiple arguments

# %%
num1,num2 = 10,20
add = num1 + num2
print(add)
# Out:
# 30

# %%
num1,num2 = 10,20
add = num1 + num2
print('The Addtion of',num1,'and',num2,'is:',add)
# Out:
# The Addtion of 10 and 20 is: 30

# %%
name = 'Divyesh'
age =38
city='Ahmedabad'
print('My Name is',name,'and my age is',age,'.','I am belongs to ',city)
# Out:
# My Name is Divyesh and my age is 38 . I am belongs to  Ahmedabad

# %%
num1,num2 = 10,20
add = num1 + num2
print('The Addtion of {} and {} is:{}'.format(num1,num2,add))
# Out:
# The Addtion of 10 and 20 is:30

# %%
#no of variable = no of flower braces

# %%
num1,num2,num3 = 10,20,30
add = num1 + num2 + num3
print(f'The Addtion of {num1} and {num2} and {num3}is:{add}')
# Out:
# The Addtion of 10 and 20 and 30is:60

# %%
print('Hello')
print('Divyesh Prajapati')
# Out:
# Hello
# Divyesh Prajapati

# %%
print('Hello',end=' ')
print('Divyesh Prajapati')
# Out:
# Hello Divyesh Prajapati

# %%
print('Hello Divyesh Prajapati what are you doing today ?')
# Out:
# Hello Divyesh Prajapati what are you doing today ?

# %%
print('Hello', 'Divyesh Prajapati', 'what are you doing today ?')
# Out:
# Hello Divyesh Prajapati what are you doing today ?

# %%
print('Hello', 'Divyesh Prajapati', 'what are you doing today ?',sep='-->')
# Out:
# Hello-->Divyesh Prajapati-->what are you doing today ?
